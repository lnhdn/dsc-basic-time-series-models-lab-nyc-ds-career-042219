# %% [markdown]
# # Basic Time Series Models - Lab

# %% [markdown]
# ## Introduction
#
# Now that you have an initial understanding of the the White Noise and the Random Walk model, let's try to generate some examples!

# %% [markdown]
# ## Objectives
#
# You will be able to:
# - Explain what the goal is of time series modeling
# - Understand and explain what a White Noise model is
# - Understand and explain what a Random Walk model is
# - Understand the mathematical formulations of Random Walk and White Noise models

# %% [markdown]
# ## A White Noise Model

# %% [markdown]
# To get a good sense of how a model works, it is always a good idea to generate a process. Let's consider the following example:
# - Every day in August, September and October 2018, Nina takes the subway to work. Let's ignore weekends for now and assume that Nina works every day.
# - We know that on average, it takes her 25 minutes, and the standard deviation is 4 minutes.
# - Create and visualize a time series that reflects this information.

# %% [markdown]
# Let's import pandas, numpy and matplotlib.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


np.random.seed(12) # do not change this seed.

# %% [markdown]
# Create the dates. You can do this using `pd.date_range`, more info [here](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.date_range.html).

# %%
# your code here
dates = pd.date_range(start = '2018/08/01', end = '2018/10/31')

# %%
len(dates)
# Out:
# 92

# %% [markdown]
# Generate the values for the wite noise process representing Nina's commute in August and September.

# %%
# your code here
times = np.random.normal(25,4,len(dates))

# %% [markdown]
# Create a time series with the dates and the commute times.

# %%
# your code here
time_series = pd.Series(times, index = dates)

# %% [markdown]
# Visualize the time series and set appropriate axis labels.

# %%
# your code here
time_series.plot(figsize = (10,5))
plt.xlabel('month')
plt.ylabel('minutes')
plt.show()

# %% [markdown]
# Print Nina's shortest and longest commute.

# %%
# your code here
min(times)
# Out:
# 12.41033391382408

# %%
# your code here
max(times)
# Out:
# 36.487277579955666

# %% [markdown]
# Look at the distribution of commute times.

# %%
# your code here
time_series.plot(kind = 'kde')

# %% [markdown]
# Compute the standard deviation and the mean of the commute series. The fact that the mean and standard error are constant over time is crucial!

# %%
# your code here
np.mean(times)
# Out:
# 24.437618956728116

# %%
# your code here
np.std(times)
# Out:
# 4.260100091078368

# %% [markdown]
# Now, let's look at the mean and standard error for August and October respectively.

# %%
# your code here
aug_mean = np.mean(time_series['2018/08'])
aug_std = np.std(time_series['2018/08'])
print(aug_mean , aug_std)
# Out:
# 24.010691679675514 4.648958870604993

# %%
oct_mean = np.mean(time_series['2018/10'])
oct_std = np.std(time_series['2018/10'])
print(oct_mean , oct_std)
# Out:
# 24.302794208974436 4.080768936688292

# %% [markdown]
# Because you've generated this data, you know that the mean and constant will be the same over time. But comparing mean and standard deviation over time is useful practice for real data examples to check if a process is White Noise!

# %% [markdown]
# ## A Random Walk Model

# %% [markdown]
# Remember from the lecture that the Random Walk Model:

# %% [markdown]
# - Has no specified mean or variance
# - Has a strong dependence over time
#
# Mathematically, this can be written as:
#
# $$Y_t = Y_{t-1} + \epsilon_t$$
#
# Because today's value depends on yesterday's, you need a starting value when you start off your time series. In practice, this is what the first few time series values look like:
# $$ Y_0 = \text{some specified starting value}$$
# $$Y_1= Y_{0}+ \epsilon_1 $$
# $$Y_2= Y_{1}+ \epsilon_2 = Y_{0} + \epsilon_1 + \epsilon_2  $$
# $$Y_3= Y_{2}+ \epsilon_3 = Y_{0} + \epsilon_1 + \epsilon_2 + \epsilon_3 $$
# $$\ldots $$
#
# Keeping this in mind, let's create a random walk model:
# - starting from a value of 1000 USD of a share value upon a company's first IPO (initial public offering) in 2010 until end of November of the same year, generate a random walk model with a white noise error term, which has a standard error of 10.

# %%
# keep the random seed
np.random.seed(11)

# create a series with the specified dates
ipo_dates  = pd.date_range(start = '2010/01/01', end = '2010/11/30')
price = np.random.normal(1000,10,len(ipo_dates))
price_series = pd.Series(price,index = ipo_dates)
price_series
# Out:
# 2010-01-01    1017.494547
# 2010-01-02     997.139270
# 2010-01-03     995.154349
# 2010-01-04     973.466814
# 2010-01-05     999.917154
# 2010-01-06     996.803686
# 2010-01-07     994.633706
# 2010-01-08    1003.154027
# 2010-01-09    1004.210507
# 2010-01-10     989.343970
# 2010-01-11     991.137603
# 2010-01-12     995.242665
# 2010-01-13    1006.896823
# 2010-01-14    1005.611922
# 2010-01-15     986.944515
# 2010-01-16     988.805247
# 2010-01-17    1007.368374
# 2010-01-18    1015.746341
# 2010-01-19     999.689249
# 2010-01-20     993.165534
# 2010-01-21    1010.956297
# 2010-01-22     996.904234
# 2010-01-23    1007.257522
# 2010-01-24    1015.490716
# 2010-01-25    1006.300798
# 2010-01-26    1000.734932
# 2010-01-27    1007.322714
# 2010-01-28     993.574246
# 2010-01-29     998.219068
# 2010-01-30     994.260454
#                  ...
# 2010-11-01     985.003842
# 2010-11-02    1008.670126
# 2010-11-03     990.953132
# 2010-11-04    1002.232900
# 2010-11-05    1005.744411
# 2010-11-06    1011.822252
# 2010-11-07     997.820966
# 2010-11-08     996.945609
# 2010-11-09     997.666881
# 2010-11-10     981.514148
# 2010-11-11     992.451836
# 2010-11-12     989.956160
# 2010-11-13     988.501370
# 2010-11-14    1001.676934
# 2010-11-15     996.885117
# 2010-11-16    1015.962650
# 2010-11-17    1014.889589
# 2010-11-18     981.175512
# 2010-11-19    1001.225792
# 2010-11-20     989.988355
# 2010-11-21    1005.561905
# 2010-11-22    1001.581198
# 2010-11-23    1009.305168
# 2010-11-24    1003.108328
# 2010-11-25    1007.612065
# 2010-11-26     997.014294
# 2010-11-27     974.919067
# 2010-11-28     988.149172
# 2010-11-29     991.450679
# 2010-11-30     995.098504
# Freq: D, Length: 334, dtype: float64

# %% [markdown]
# Visualize the time series with correct axis labels

# %%
# your code here
price_series.plot(figsize = (10,5))
plt.xlabel('ipo_dates')
plt.ylabel('stock price ($)')
plt.show()

# %%
np.random.seed(11)

# create a series with the specified dates
dates = pd.date_range('2010-01-01', '2010-11-30')
len(dates)

error = np.random.normal(0,10,len(dates))
print(error)

def random_walk(start, error):        
    Y_0 = start
    cum_error = np.cumsum(error)
    print('cumerror',cum_error)
    Y = cum_error + Y_0 
    print(Y)
    return Y

shares_value = random_walk(1000, error)

shares_series =  pd.Series(shares_value, index=dates)
# Out:
# [ 17.49454741  -2.86072997  -4.84565132 -26.53318559  -0.08284629
#   -3.19631364  -5.36629362   3.15402668   4.21050716 -10.6560298
#   -8.8623967   -4.75733493   6.8968231    5.61192176 -13.0554851
#  -11.19475262   7.36837391  15.74634073  -0.31075088  -6.83446627
#   959.67011412  968.97528247  972.0836106   979.69567547  976.70996945
#   951.62903667  939.77820834  931.2288877   926.32739217]

# %%
shares_series.plot()

# %% [markdown]
# You can see how this very much looks like the exchange rate series you looked at in the lecture!

# %% [markdown]
# ## Random Walk with a Drift
#
# Repeat the above, but include a drift parameter $c$ of 8 now!

# %%
# keep the random seed

# %%
# your code here
np.random.seed(11)

# create a series with the specified dates
dates = pd.date_range('2010-01-01', '2010-11-30')
len(dates)

error = np.random.normal(0,10,len(dates))
print(error)

def random_walk_drift(start, error, c):        
    Y_0 = start
    cum_error = np.cumsum(error)
    Y = cum_error + Y_0 + c
    return Y

shares_value_1 = random_walk_drift(1000, error, 8)

shares_series_1 =  pd.Series(shares_value, index=dates)
# Out:
# [ 17.49454741  -2.86072997  -4.84565132 -26.53318559  -0.08284629
#   -3.19631364  -5.36629362   3.15402668   4.21050716 -10.6560298
#   -8.8623967   -4.75733493   6.8968231    5.61192176 -13.0554851
#  -11.19475262   7.36837391  15.74634073  -0.31075088  -6.83446627
#   10.95629699  -3.09576637   7.25752225  15.49071633   6.30079822
#    0.73493237   7.32271354  -6.42575392  -1.78093175  -5.73954559
#   -2.04375316  -4.864951    -1.85775324  -3.80536417   0.88977635
#    0.63671661   2.96347108  14.02771119 -15.46862568  12.95618585
#   -2.37250446 -12.32346207  -1.72419767   0.91838375  10.67558457
#  -10.61634448   2.17348208   1.17819504 -16.84110893 -11.85755265
#    6.00102006   6.95567255  10.8771086    5.33821716   3.95212013
#    1.22867529  12.09101642  -8.43066101  -1.41893581   3.85354138
#  -15.77494309  13.1094364   -7.92865008  -0.71749412  21.56674426
#   -8.29437252  -5.29372028  15.61703694 -10.80193825  -4.32057619
#    5.16084037   4.5539286    5.93686203   3.70506334  13.45378072
#   10.15942146   5.95278454  -6.82801616  -7.13559929 -19.08289542
#    6.87312349 -18.23009584   8.791138    18.46364873 -10.61654404
#   -6.84484668  -4.7621448    8.3031043   -8.63352516  -1.30541467
#   -5.23087633  -2.51276924  12.91274728  -9.64204853   0.71759774
#    2.71606296   8.58667174 -12.64073679  11.14870285   4.34776987
#    8.74272766   0.716521   -16.39051627  -6.47302631   8.17769566
#    0.36794754  -0.48702542  17.91531097  22.01856314  -0.37066904
#   19.32905428 -19.93571531 -20.4905726    8.67055208  -2.61961073
#    5.78971107   5.16552386  -0.8940364    6.8212971    1.50722009
#  -15.32142522   2.18868577   1.85663254  18.32776537 -11.28894401
#    0.16996881  -4.24428825  -1.32909899  16.59204618   3.78640684
#   -4.64566062   1.53841245   7.6616062   -9.94027693  -2.64342329
#   15.4220922    8.56152046  -0.44802617  -4.77489229  -1.54065524
#  -15.51079461   9.43035981   3.41153439   1.38273217 -12.97422618
#   -7.14962444   5.14479633   2.57716381  -4.96730477   5.05021917
#    9.38783125  -6.75020275  -5.3085824   -8.69861944 -11.55264225
#    7.96671847   5.10028022   3.38713936 -11.72120035 -10.45967655
#   -0.67668564  -4.13209753   1.200828    -6.98971686   6.54024882
#   17.99480074  15.46606095  16.09873985   0.7101978    9.21575231
#   -3.76829843   9.19982543  -3.78422554  -4.88975435  -6.44393817
#    6.99140837   2.75406658   1.86325341 -11.39805652   1.41804891
#  -14.40719354  14.76512824  -1.31553483   1.94429202  -1.05149253
#  -15.83962579 -13.71773686  -0.28318338  14.92471499 -11.15237216
#   -7.05414026  -0.47232575 -16.87280607 -16.97342115  -4.11453942
#   -0.45275143  -3.91173133  15.3422235   -1.64192947   3.60366653
#   15.98049901  17.03721823 -15.89519894  -3.77246517  11.6250551
#  -13.78858707  -9.2399568  -12.9751339  -13.61934228 -11.3418537
#    1.76842752  12.68925515  15.28022877   0.11887983 -19.70571887
#   -0.56632585  -3.39202415   3.52321122  -1.28413112 -17.96113096
#    4.13283446 -20.67835437  -6.90111214   3.11750714   3.50366567
#   15.71348006 -23.62413593   3.39984209   6.89380345  -3.27214137
#    6.38031524 -11.01998631   6.5702758    5.38215247  -9.81629654
#   -6.66639813  -1.89823936  -6.56085353  10.44397082   1.75167466
#   13.14733331  11.75249567   0.60847012  -1.93104579  -9.46655655
#   -8.04610624  -8.01191118   3.47850538  -8.83665815   0.78658282
#    1.92589128  -4.9623431   -1.86224544  14.45369908  16.1198152
#   -7.82633025  -1.94613444  -3.72132047  -2.75766545  15.35137836
#    6.86454638  12.59915716  17.76879488  -4.403135    -1.8720727
#    0.40406583  10.26036481  -0.90997807   6.45786326  11.68308637
#   11.63230321   4.46678891  -7.88715428 -15.54102098  11.21633081
#    4.56599937  -9.37475882  -5.05076178  -4.48800499 -16.74949001
#    2.51546094  -7.87039139  -2.94406733   7.39700706  -0.95635905
#    5.43053195   4.22385239   0.31669127   0.48830976  18.61613356
#   -1.70675893  16.27672044  -9.14000703   7.29400692   1.70905427
#   -7.29254437 -26.47464526  15.94924715 -11.55204048  -9.63054051
#    1.29630012   0.57139143   2.78796114  -2.54078142 -14.99615828
#    8.67012621  -9.04686782   2.23289986   5.74441133  11.82225227
#   -2.17903411  -3.05439059  -2.33311919 -18.48585189  -7.54816358
#  -10.04384039 -11.49863043   1.67693391  -3.11488255  15.9626504
#   14.88958882 -18.82448834   1.22579216 -10.01164482   5.56190535
#    1.58119755   9.30516835   3.10832813   7.61206486  -2.98570602
#  -25.08093278 -11.85082832  -8.54932065  -4.90149553]

# %%
shares_series_1.plot()
shares_series.plot()
plt.show()

# %% [markdown]
# Note that there is a very strong drift here!

# %% [markdown]
# ## Differencing in a Random Walk model

# %% [markdown]
# One important property of the Random Walk model is that a differenced random walk returns a white noise. This is a result of the mathematical formula:
#
# $$Y_t = Y_{t-1} + \epsilon_t$$
# which is equivalent to
# $$Y_t - Y_{t-1} = \epsilon_t$$
#
# and we know that $\epsilon_t$ is a mean-zero white noise process!

# %% [markdown]
# Plot the differenced time series for the shares time series (no drift).

# %%
# your code here

# %% [markdown]
# This does look a lot like a white noise series!

# %% [markdown]
# Plot the differenced time series for the shares time series (with a drift).

# %%
# your code here

# %% [markdown]
# This is also a white noise series, but what can you tell about the mean?

# %% [markdown]
# The mean is equal to the drift $c$, so 8 for this example!

# %% [markdown]
# ## Summary
#
# Great, you now know how a Random Walk and Moving Average model work!
